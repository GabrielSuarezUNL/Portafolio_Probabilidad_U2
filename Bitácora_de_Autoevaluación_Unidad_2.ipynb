# %% [markdown]
# # 📝 Bitácora de Autoevaluación - Unidad 2: Inferencia Estadística
# **Estudiante:** [Tu Nombre]
# **Proyecto:** Proyecto Integrador Regional (PID-2025)
#
# ### 1. Aprendizajes Logrados en la Unidad
# - **Tránsito Científico:** Logré migrar con éxito de la estadística puramente descriptiva (gráficos y promedios) hacia el pensamiento inferencial paramétrico, entendiendo cómo una muestra permite tomar decisiones sobre toda una población bajo un margen de error controlado ($\alpha$).
# - **Uso de Librerías Científicas:** Aprendí a usar las abstracciones de alto nivel de `scipy.stats` y `statsmodels` para calcular valores de probabilidad reales sin tratar al software como una "caja negra".
# - **Ecuaciones en LaTeX:** Dominé la escritura matemática en Markdown para documentar hipótesis nulas ($H_0$) y alternas ($H_1$) formalmente.
#
# ### 2. Dificultades Algorítmicas Superadas
# - **Limpieza de Datos Cruda:** El mayor reto técnico fue procesar las columnas del dataset del Municipio de Loja, ya que contenían espacios en blanco y formatos de texto que hacían fallar los cálculos de `scipy`. Lo superé aplicando `pd.to_numeric(..., errors='coerce')` y removiendo los valores `NaN`.
# - **Sintaxis de Fórmulas en Statsmodels:** La función `ols()` fallaba inicialmente debido a los espacios en los nombres de las columnas como *"Régimen laboral al que pertenece "*. Aprendí a solucionar esto utilizando la abstracción de encapsulamiento `Q("Nombre de la Columna")` dentro de la fórmula del modelo lineal.
#
# ### 3. Compromiso de Mejora
# Para las siguientes unidades, profundizaré en el análisis de supuestos previos  antes de asumir directamente que los datos cumplen las condiciones paramétricas.
